# %%
import pandas as pd 
df=pd.read_excel("/home/kholi/IPL SCHEDULE/IPL-2023-Schedule-Excel.xlsx")
df.fillna(1300,inplace=False)
print(df.to_string())
# Out:
#    IPL 2023 Venue  Unnamed: 1             Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8 Teams Schedule
# 0       Ahmedabad         NaN                    NaN         NaN         NaN         NaN         NaN         NaN         NaN             MI
# 1          Mohali         NaN                    NaN         NaN         NaN         NaN         NaN         NaN         NaN            CSK
# 2         Lucknow         NaN                    NaN         NaN         NaN         NaN         NaN         NaN         NaN            LSG
# 3       Hyderabad         NaN                    NaN         NaN         NaN         NaN         NaN         NaN         NaN           PBKS
# 4       Bengaluru         NaN                    NaN         NaN         NaN         NaN         NaN         NaN         NaN            SRH
# 5         Chennai         NaN                    NaN         NaN         NaN         NaN         NaN         NaN         NaN            KKR
# ...

# %% [markdown]
# # from tabula import read_pdf
# import ssl
# import pandas as pd
# url="https://www.icccricketschedule.com/wp-content/uploads/2023/02/IPL-2023-Schedule-PDF.pdf"
# try:
#     df=pd.read_pdf(url)
#     print(df)
# except Exception as e:
#     print(e)

# %%
import pandas as pd
df=pd.read_csv("trade-survey.csv")
print(df.to_string())
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  Magnitude                       Subject                                                                           Group                                     Series_title_1            Series_title_2  Series_title_3       Series_title_4                                    Series_title_5
# 0         WTSQ.SFA1CA  1995.03    2368.690         NaN      F  Dollars          6  Wholesale Trade Survey - WTS              Industry by variable - (ANZSIC06) - Subannual Financial Collection                         Basic material wholesaling  Sales (operating income)  Current prices           Unadjusted                                               NaN
# ...

# %% [markdown]
# # import pandas as pd
# df=pd.read_csv("kholi.csv")
# print(df.head(20))

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("trade-survey.csv")
df.plot()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("access-code-password-recovery-code.csv")
print(df.to_string())
# Out:
#    Identifier Access code Recovery code First name Last name  \
# 0        9012      12se74        rb9012     Rachel    Booker
# 1        2070      04ap67        lg2070      Laura      Grey
# 2        4081      30no86        cj4081      Craig   Johnson
# 3        9346      14ju73        mj9346       Mary   Jenkins
# 4        5079      09ja61        js5079      Jamie     Smith
# 5        8075     45jdhj5       hd89nbh      Kholi       vox
# 6        2647      hcsyjk           NaN        NaN     jeeva
#
#           Department    Location
# 0              Sales  Manchester
# 1              Depot      London
# 2              Depot      London
# 3        Engineering  Manchester
# 4        Engineering  Manchester
# 5  data scientistist       india
# 6               army        pune
