# %%
import pandas as pd 
df=pd.read_excel("/home/kholi/IPL SCHEDULE/IPL-2023-Schedule-Excel.xlsx")
df.fillna("kholi",inplace=True)
print(df.to_string())
# Out:
#    IPL 2023 Venue Unnamed: 1             Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Teams Schedule
# 0       Ahmedabad      kholi                  kholi      kholi      kholi      kholi      kholi      kholi      kholi             MI
# 1          Mohali      kholi                  kholi      kholi      kholi      kholi      kholi      kholi      kholi            CSK
# 2         Lucknow      kholi                  kholi      kholi      kholi      kholi      kholi      kholi      kholi            LSG
# 3       Hyderabad      kholi                  kholi      kholi      kholi      kholi      kholi      kholi      kholi           PBKS
# 4       Bengaluru      kholi                  kholi      kholi      kholi      kholi      kholi      kholi      kholi            SRH
# 5         Chennai      kholi                  kholi      kholi      kholi      kholi      kholi      kholi      kholi            KKR
# ...

# %% [markdown]
# # from tabula import read_pdf
# import ssl
# import pandas as pd
# url="https://www.icccricketschedule.com/wp-content/uploads/2023/02/IPL-2023-Schedule-PDF.pdf"
# try:
#     df=pd.read_pdf(url)
#     print(df)
# except Exception as e:
#     print(e)

# %%
import pandas as pd
df=pd.read_csv("trade-survey.csv")
print(df.to_string())
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  Magnitude                       Subject                                                                           Group                                     Series_title_1            Series_title_2  Series_title_3       Series_title_4                                    Series_title_5
# 0         WTSQ.SFA1CA  1995.03    2368.690         NaN      F  Dollars          6  Wholesale Trade Survey - WTS              Industry by variable - (ANZSIC06) - Subannual Financial Collection                         Basic material wholesaling  Sales (operating income)  Current prices           Unadjusted                                               NaN
# ...

# %% [markdown]
# # import pandas as pd
# df=pd.read_csv("kholi.csv")
# print(df.head(20))

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("trade-survey.csv")
df.plot()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("access-code-password-recovery-code.csv")
df.fillna(1300,inplace=True)
print(df.to_string())
# Out:
#    Identifier Access code Recovery code First name Last name         Department    Location
# 0        9012      12se74        rb9012     Rachel    Booker              Sales  Manchester
# 1        2070      04ap67        lg2070      Laura      Grey              Depot      London
# 2        4081      30no86        cj4081      Craig   Johnson              Depot      London
# 3        9346      14ju73        mj9346       Mary   Jenkins        Engineering  Manchester
# 4        5079      09ja61        js5079      Jamie     Smith        Engineering  Manchester
# 5        8075     45jdhj5       hd89nbh      Kholi       vox  data scientistist       india
# 6        2647      hcsyjk          1300       1300     jeeva               army        pune

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("access-code-password-recovery-code.csv")
df.plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/home/kholi/pandas/dirtydata.csv")
df.plot()
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/home/kholi/pandas/dirtydata.csv')

x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)

print(df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
import pandas as pd
df=pd.read_csv("/home/kholi/pandas/dirtydata.csv")
df["Date"]=pd.to_datetime(df["Date"])
df.fillna(1200,inplace=True)
print(df.to_string())
# Out:
#     Duration                 Date  Pulse  Maxpulse  Calories
# 0         60  2020-12-01 00:00:00    110       130     409.1
# 1         60  2020-12-02 00:00:00    117       145     479.0
# 2         60  2020-12-03 00:00:00    103       135     340.0
# 3         45  2020-12-04 00:00:00    109       175     282.4
# 4         45  2020-12-05 00:00:00    117       148     406.0
# 5         60  2020-12-06 00:00:00    102       127     300.0
# 6         60  2020-12-07 00:00:00    110       136     374.0
# 7        450  2020-12-08 00:00:00    104       134     253.3
# 8         30  2020-12-09 00:00:00    109       133     195.1
# 9         60  2020-12-10 00:00:00     98       124     269.0
# 10        60  2020-12-11 00:00:00    103       147     329.3
# 11        60  2020-12-12 00:00:00    100       120     250.7
# 12        60  2020-12-12 00:00:00    100       120     250.7
# 13        60  2020-12-13 00:00:00    106       128     345.3
# ...

# %%
import pandas as pd
df=pd.read_csv("Grading of the students in the exam (OR).csv")
print(df.to_string())
# Out:
#     Class Roll  CT-1 (Marks: 20)  CT-2 (Marks: 20)  CT-3 (Marks: 20)  CT-4 (Marks: 20)  CT-5 (Marks: 20)  Class Test (Total of best 4, Marks: 80)  Attendance (Marks: 20)  Observation (Marks: 20)  Total (Marks: 120)                             Sec A (140)   Sec B  Final Mark
# 0          100               8.5               2.0                11              12.0              16.0                                     47.5                      20                       17                84.5                                      57   93.00     58.6250
# 1          101               7.0               3.0                 9              15.0              11.0                                     42.0                      20                        8                70.0                                      83   55.00     52.0000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Grading of the students in the exam (OR).csv")
df.plot()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("Metadata_Country_API_SI.POV.DDAY_DS2_en_csv_v2_5349804.csv")
df.fillna("india",inplace=True)
print(df.to_string())
# Out:
#     Country Code                      Region          IncomeGroup                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Metadata_Country_API_SI.POV.DDAY_DS2_en_csv_v2_5349804.csv")
df.plot()
plt.title("kholi vox")
plt.xlabel("YEAR",)
plt.ylabel("DATA")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("dirtydata.csv")
df['Date']=pd.to_datetime(df["Date"])
df.dropna(subset=["Date"],inplace=True)
print(df)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#Duration change
import pandas as pd
df=pd.read_csv("dirtydata.csv")
df.loc[7,"Duration"]=120
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        120  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#many data change concept
import pandas as pd
df=pd.read_csv("dirtydata.csv")
for x in df.index:
    if df.loc[x,"Duration"]>120:
        df.drop(x,inplace=True)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...
